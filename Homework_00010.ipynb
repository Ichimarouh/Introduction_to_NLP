# %% [markdown]
# ## Введение в обработку естественного языка

# %% [markdown]
# ### Урок 10. Машинный перевод. Модель seq2seq и механизм внимания

# %% [markdown]
# Разобраться с моделькой перевода как она устроена
# запустить для перевода с русского на английский (при желании можно взять другие пары языков) два варианта с вниманием и без внимания
# оценить качество насколько корректно переводит (для теста отобрать примеры с увеличением длины текста) (так как оценка визуальная достаточно 20-ти примеров в тестовой выборке)

# %%
import numpy as np

import tensorflow as tf

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import unicodedata

import re

import os

import io

import time

# %% [markdown]
# **Произведем загрузку данных.**

# %%
path_to_file = "rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  w = '<start> ' + w + ' <end>'
  
  return w

# %%
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)

print(en[100])

print(ru[100])
# Out:
# <start> eat it . <end>
# <start> съешьте е . <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):

  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
len(ru)
# Out:
# 451436

# %%
num_examples = 100000

input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")

convert(inp_lang, input_tensor_train[0])

print()

print ("Target Language; index to word mapping")

convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 1518 ----> отпустите
# 16516 ----> канат
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 86 ----> let
# 27 ----> go
# 72 ----> of
# 12 ----> the
# 833 ----> rope
# 3 ----> .
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)

BATCH_SIZE = 64

steps_per_epoch = len(input_tensor_train)//BATCH_SIZE

embedding_dim = 300

units = 1024

vocab_inp_size = len(inp_lang.word_index)+1

vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)

dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))

example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    
  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

sample_hidden = encoder.initialize_hidden_state()

sample_hidden = encoder(example_input_batch, sample_hidden)

print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state=hidden)
    output = tf.reshape(output, (-1, output.shape[2]))
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
# !rm -rf ./training_checkpoints

checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    for t in range(1, targ.shape[1]):
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)
      
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.7536
# Epoch 1 Batch 100 Loss 1.9275
# Epoch 1 Batch 200 Loss 1.8115
# Epoch 1 Batch 300 Loss 1.7697
# Epoch 1 Batch 400 Loss 1.4671
# Epoch 1 Batch 500 Loss 1.4210
# Epoch 1 Batch 600 Loss 1.4547
# Epoch 1 Batch 700 Loss 1.2914
# Epoch 1 Batch 800 Loss 1.2916
# Epoch 1 Batch 900 Loss 1.1638
# Epoch 1 Batch 1000 Loss 1.1339
# Epoch 1 Batch 1100 Loss 1.1122
# Epoch 1 Batch 1200 Loss 1.0870
# Epoch 1 Loss 1.4724
# Time taken for 1 epoch 71.33579087257385 sec
#
# Epoch 2 Batch 0 Loss 0.9276
# Epoch 2 Batch 100 Loss 0.9901
# Epoch 2 Batch 200 Loss 0.9012
# Epoch 2 Batch 300 Loss 0.7973
# Epoch 2 Batch 400 Loss 0.8824
# Epoch 2 Batch 500 Loss 0.8794
# Epoch 2 Batch 600 Loss 0.7962
# Epoch 2 Batch 700 Loss 0.8756
# Epoch 2 Batch 800 Loss 0.7791
# Epoch 2 Batch 900 Loss 0.8084
# Epoch 2 Batch 1000 Loss 0.6079
# Epoch 2 Batch 1100 Loss 0.6706
# Epoch 2 Batch 1200 Loss 0.6931
# Epoch 2 Loss 0.7952
# Time taken for 1 epoch 59.35050129890442 sec
#
# Epoch 3 Batch 0 Loss 0.5745
# Epoch 3 Batch 100 Loss 0.5533
# Epoch 3 Batch 200 Loss 0.5394
# Epoch 3 Batch 300 Loss 0.4969
# Epoch 3 Batch 400 Loss 0.5310
# Epoch 3 Batch 500 Loss 0.4804
# Epoch 3 Batch 600 Loss 0.3671
# Epoch 3 Batch 700 Loss 0.4667
# Epoch 3 Batch 800 Loss 0.5306
# Epoch 3 Batch 900 Loss 0.3679
# Epoch 3 Batch 1000 Loss 0.3712
# Epoch 3 Batch 1100 Loss 0.4826
# Epoch 3 Batch 1200 Loss 0.4003
# Epoch 3 Loss 0.4617
# Time taken for 1 epoch 58.71549701690674 sec
#
# Epoch 4 Batch 0 Loss 0.2771
# Epoch 4 Batch 100 Loss 0.2820
# Epoch 4 Batch 200 Loss 0.2703
# Epoch 4 Batch 300 Loss 0.2071
# Epoch 4 Batch 400 Loss 0.3079
# Epoch 4 Batch 500 Loss 0.2706
# Epoch 4 Batch 600 Loss 0.2276
# Epoch 4 Batch 700 Loss 0.2773
# Epoch 4 Batch 800 Loss 0.3142
# Epoch 4 Batch 900 Loss 0.2485
# Epoch 4 Batch 1000 Loss 0.3067
# Epoch 4 Batch 1100 Loss 0.3089
# Epoch 4 Batch 1200 Loss 0.2907
# Epoch 4 Loss 0.2745
# Time taken for 1 epoch 59.46798133850098 sec
#
# Epoch 5 Batch 0 Loss 0.2197
# Epoch 5 Batch 100 Loss 0.1381
# Epoch 5 Batch 200 Loss 0.1518
# Epoch 5 Batch 300 Loss 0.1657
# Epoch 5 Batch 400 Loss 0.1699
# Epoch 5 Batch 500 Loss 0.1709
# Epoch 5 Batch 600 Loss 0.1584
# Epoch 5 Batch 700 Loss 0.1764
# Epoch 5 Batch 800 Loss 0.2060
# Epoch 5 Batch 900 Loss 0.1772
# Epoch 5 Batch 1000 Loss 0.2128
# Epoch 5 Batch 1100 Loss 0.1929
# Epoch 5 Batch 1200 Loss 0.1746
# Epoch 5 Loss 0.1787
# Time taken for 1 epoch 58.84016299247742 sec
#
# Epoch 6 Batch 0 Loss 0.1221
# Epoch 6 Batch 100 Loss 0.0873
# Epoch 6 Batch 200 Loss 0.1454
# Epoch 6 Batch 300 Loss 0.1037
# Epoch 6 Batch 400 Loss 0.1499
# Epoch 6 Batch 500 Loss 0.1293
# Epoch 6 Batch 600 Loss 0.1298
# Epoch 6 Batch 700 Loss 0.1508
# Epoch 6 Batch 800 Loss 0.1393
# Epoch 6 Batch 900 Loss 0.1156
# Epoch 6 Batch 1000 Loss 0.1598
# Epoch 6 Batch 1100 Loss 0.1319
# Epoch 6 Batch 1200 Loss 0.1493
# Epoch 6 Loss 0.1314
# Time taken for 1 epoch 59.40405869483948 sec
#
# Epoch 7 Batch 0 Loss 0.0784
# Epoch 7 Batch 100 Loss 0.1165
# Epoch 7 Batch 200 Loss 0.0762
# Epoch 7 Batch 300 Loss 0.1010
# Epoch 7 Batch 400 Loss 0.1156
# Epoch 7 Batch 500 Loss 0.1009
# Epoch 7 Batch 600 Loss 0.1110
# Epoch 7 Batch 700 Loss 0.0898
# Epoch 7 Batch 800 Loss 0.1531
# Epoch 7 Batch 900 Loss 0.0972
# Epoch 7 Batch 1000 Loss 0.1421
# Epoch 7 Batch 1100 Loss 0.1437
# Epoch 7 Batch 1200 Loss 0.1746
# Epoch 7 Loss 0.1067
# Time taken for 1 epoch 58.85399031639099 sec
#
# Epoch 8 Batch 0 Loss 0.0717
# Epoch 8 Batch 100 Loss 0.0635
# Epoch 8 Batch 200 Loss 0.0682
# Epoch 8 Batch 300 Loss 0.0751
# Epoch 8 Batch 400 Loss 0.0869
# Epoch 8 Batch 500 Loss 0.1091
# Epoch 8 Batch 600 Loss 0.0447
# Epoch 8 Batch 700 Loss 0.1055
# Epoch 8 Batch 800 Loss 0.0783
# Epoch 8 Batch 900 Loss 0.1010
# Epoch 8 Batch 1000 Loss 0.1107
# Epoch 8 Batch 1100 Loss 0.0960
# Epoch 8 Batch 1200 Loss 0.0982
# Epoch 8 Loss 0.0932
# Time taken for 1 epoch 59.4728467464447 sec
#
# Epoch 9 Batch 0 Loss 0.0513
# Epoch 9 Batch 100 Loss 0.0735
# Epoch 9 Batch 200 Loss 0.0774
# Epoch 9 Batch 300 Loss 0.0467
# Epoch 9 Batch 400 Loss 0.0857
# Epoch 9 Batch 500 Loss 0.1233
# Epoch 9 Batch 600 Loss 0.0941
# Epoch 9 Batch 700 Loss 0.0775
# Epoch 9 Batch 800 Loss 0.0796
# Epoch 9 Batch 900 Loss 0.1130
# Epoch 9 Batch 1000 Loss 0.1204
# Epoch 9 Batch 1100 Loss 0.0906
# Epoch 9 Batch 1200 Loss 0.1036
# Epoch 9 Loss 0.0857
# Time taken for 1 epoch 58.79279613494873 sec
#
# Epoch 10 Batch 0 Loss 0.0655
# Epoch 10 Batch 100 Loss 0.0575
# Epoch 10 Batch 200 Loss 0.0694
# Epoch 10 Batch 300 Loss 0.0779
# Epoch 10 Batch 400 Loss 0.0864
# Epoch 10 Batch 500 Loss 0.0561
# Epoch 10 Batch 600 Loss 0.0705
# Epoch 10 Batch 700 Loss 0.1144
# Epoch 10 Batch 800 Loss 0.0874
# Epoch 10 Batch 900 Loss 0.1256
# Epoch 10 Batch 1000 Loss 0.1353
# Epoch 10 Batch 1100 Loss 0.1035
# Epoch 10 Batch 1200 Loss 0.1017
# Epoch 10 Loss 0.0807
# Time taken for 1 epoch 59.48480939865112 sec
#
# Epoch 11 Batch 0 Loss 0.0568
# Epoch 11 Batch 100 Loss 0.0632
# Epoch 11 Batch 200 Loss 0.0556
# Epoch 11 Batch 300 Loss 0.0481
# Epoch 11 Batch 400 Loss 0.0617
# Epoch 11 Batch 500 Loss 0.0456
# Epoch 11 Batch 600 Loss 0.1038
# Epoch 11 Batch 700 Loss 0.0873
# Epoch 11 Batch 800 Loss 0.1082
# Epoch 11 Batch 900 Loss 0.0863
# Epoch 11 Batch 1000 Loss 0.0540
# Epoch 11 Batch 1100 Loss 0.1501
# Epoch 11 Batch 1200 Loss 0.1466
# Epoch 11 Loss 0.0761
# Time taken for 1 epoch 58.76474666595459 sec
#
# Epoch 12 Batch 0 Loss 0.0990
# Epoch 12 Batch 100 Loss 0.0522
# Epoch 12 Batch 200 Loss 0.0555
# Epoch 12 Batch 300 Loss 0.0566
# Epoch 12 Batch 400 Loss 0.0709
# Epoch 12 Batch 500 Loss 0.0737
# Epoch 12 Batch 600 Loss 0.0550
# Epoch 12 Batch 700 Loss 0.0749
# Epoch 12 Batch 800 Loss 0.0952
# Epoch 12 Batch 900 Loss 0.0711
# Epoch 12 Batch 1000 Loss 0.1182
# Epoch 12 Batch 1100 Loss 0.0397
# Epoch 12 Batch 1200 Loss 0.1247
# Epoch 12 Loss 0.0726
# Time taken for 1 epoch 59.42252230644226 sec
#
# Epoch 13 Batch 0 Loss 0.0643
# Epoch 13 Batch 100 Loss 0.0482
# Epoch 13 Batch 200 Loss 0.0609
# Epoch 13 Batch 300 Loss 0.0787
# Epoch 13 Batch 400 Loss 0.0680
# Epoch 13 Batch 500 Loss 0.0534
# Epoch 13 Batch 600 Loss 0.0593
# Epoch 13 Batch 700 Loss 0.0983
# Epoch 13 Batch 800 Loss 0.0661
# Epoch 13 Batch 900 Loss 0.0398
# Epoch 13 Batch 1000 Loss 0.0750
# Epoch 13 Batch 1100 Loss 0.0541
# Epoch 13 Batch 1200 Loss 0.1012
# Epoch 13 Loss 0.0703
# Time taken for 1 epoch 58.74947476387024 sec
#
# Epoch 14 Batch 0 Loss 0.0741
# Epoch 14 Batch 100 Loss 0.0574
# Epoch 14 Batch 200 Loss 0.0452
# Epoch 14 Batch 300 Loss 0.0597
# Epoch 14 Batch 400 Loss 0.0443
# Epoch 14 Batch 500 Loss 0.0355
# Epoch 14 Batch 600 Loss 0.0971
# Epoch 14 Batch 700 Loss 0.0890
# Epoch 14 Batch 800 Loss 0.0908
# Epoch 14 Batch 900 Loss 0.0855
# Epoch 14 Batch 1000 Loss 0.0915
# Epoch 14 Batch 1100 Loss 0.0749
# Epoch 14 Batch 1200 Loss 0.0783
# Epoch 14 Loss 0.0677
# Time taken for 1 epoch 59.48922610282898 sec
#
# Epoch 15 Batch 0 Loss 0.0458
# Epoch 15 Batch 100 Loss 0.0392
# Epoch 15 Batch 200 Loss 0.0135
# Epoch 15 Batch 300 Loss 0.0564
# Epoch 15 Batch 400 Loss 0.0492
# Epoch 15 Batch 500 Loss 0.0941
# Epoch 15 Batch 600 Loss 0.0612
# Epoch 15 Batch 700 Loss 0.0553
# Epoch 15 Batch 800 Loss 0.1060
# Epoch 15 Batch 900 Loss 0.0678
# Epoch 15 Batch 1000 Loss 0.0513
# Epoch 15 Batch 1100 Loss 0.0905
# Epoch 15 Batch 1200 Loss 0.0680
# Epoch 15 Loss 0.0663
# Time taken for 1 epoch 58.77074480056763 sec
#
# Epoch 16 Batch 0 Loss 0.0619
# Epoch 16 Batch 100 Loss 0.0487
# Epoch 16 Batch 200 Loss 0.0326
# Epoch 16 Batch 300 Loss 0.0760
# Epoch 16 Batch 400 Loss 0.0705
# Epoch 16 Batch 500 Loss 0.0751
# Epoch 16 Batch 600 Loss 0.0765
# Epoch 16 Batch 700 Loss 0.0742
# Epoch 16 Batch 800 Loss 0.0612
# Epoch 16 Batch 900 Loss 0.0666
# Epoch 16 Batch 1000 Loss 0.0760
# Epoch 16 Batch 1100 Loss 0.0518
# Epoch 16 Batch 1200 Loss 0.0832
# Epoch 16 Loss 0.0642
# Time taken for 1 epoch 59.51912045478821 sec
#
# Epoch 17 Batch 0 Loss 0.0563
# Epoch 17 Batch 100 Loss 0.0520
# Epoch 17 Batch 200 Loss 0.0516
# Epoch 17 Batch 300 Loss 0.0406
# Epoch 17 Batch 400 Loss 0.0813
# Epoch 17 Batch 500 Loss 0.0567
# Epoch 17 Batch 600 Loss 0.0478
# Epoch 17 Batch 700 Loss 0.0600
# Epoch 17 Batch 800 Loss 0.0681
# Epoch 17 Batch 900 Loss 0.0628
# Epoch 17 Batch 1000 Loss 0.0776
# Epoch 17 Batch 1100 Loss 0.1253
# Epoch 17 Batch 1200 Loss 0.0820
# Epoch 17 Loss 0.0627
# Time taken for 1 epoch 58.79778575897217 sec
#
# Epoch 18 Batch 0 Loss 0.0538
# Epoch 18 Batch 100 Loss 0.0336
# Epoch 18 Batch 200 Loss 0.0497
# Epoch 18 Batch 300 Loss 0.0421
# Epoch 18 Batch 400 Loss 0.0818
# Epoch 18 Batch 500 Loss 0.0697
# Epoch 18 Batch 600 Loss 0.0534
# Epoch 18 Batch 700 Loss 0.0796
# Epoch 18 Batch 800 Loss 0.0803
# Epoch 18 Batch 900 Loss 0.0801
# Epoch 18 Batch 1000 Loss 0.1021
# Epoch 18 Batch 1100 Loss 0.0965
# Epoch 18 Batch 1200 Loss 0.1233
# Epoch 18 Loss 0.0617
# Time taken for 1 epoch 59.655336141586304 sec
#
# Epoch 19 Batch 0 Loss 0.0531
# Epoch 19 Batch 100 Loss 0.0448
# Epoch 19 Batch 200 Loss 0.0698
# Epoch 19 Batch 300 Loss 0.0622
# Epoch 19 Batch 400 Loss 0.0680
# Epoch 19 Batch 500 Loss 0.0344
# Epoch 19 Batch 600 Loss 0.0713
# Epoch 19 Batch 700 Loss 0.0849
# Epoch 19 Batch 800 Loss 0.0450
# Epoch 19 Batch 900 Loss 0.0650
# Epoch 19 Batch 1000 Loss 0.0634
# Epoch 19 Batch 1100 Loss 0.0460
# Epoch 19 Batch 1200 Loss 0.1161
# Epoch 19 Loss 0.0606
# Time taken for 1 epoch 58.743314027786255 sec
#
# Epoch 20 Batch 0 Loss 0.0691
# Epoch 20 Batch 100 Loss 0.0659
# Epoch 20 Batch 200 Loss 0.0514
# Epoch 20 Batch 300 Loss 0.1021
# Epoch 20 Batch 400 Loss 0.0584
# Epoch 20 Batch 500 Loss 0.0409
# Epoch 20 Batch 600 Loss 0.0442
# Epoch 20 Batch 700 Loss 0.0555
# Epoch 20 Batch 800 Loss 0.0604
# Epoch 20 Batch 900 Loss 0.0757
# Epoch 20 Batch 1000 Loss 0.0593
# Epoch 20 Batch 1100 Loss 0.0674
# Epoch 20 Batch 1200 Loss 0.0673
# Epoch 20 Loss 0.0590
# Time taken for 1 epoch 59.393035650253296 sec
#
# Epoch 21 Batch 0 Loss 0.0780
# Epoch 21 Batch 100 Loss 0.0602
# Epoch 21 Batch 200 Loss 0.0671
# Epoch 21 Batch 300 Loss 0.0456
# Epoch 21 Batch 400 Loss 0.0380
# Epoch 21 Batch 500 Loss 0.0633
# Epoch 21 Batch 600 Loss 0.0756
# Epoch 21 Batch 700 Loss 0.0624
# Epoch 21 Batch 800 Loss 0.0671
# Epoch 21 Batch 900 Loss 0.0581
# Epoch 21 Batch 1000 Loss 0.0850
# Epoch 21 Batch 1100 Loss 0.0828
# Epoch 21 Batch 1200 Loss 0.0963
# Epoch 21 Loss 0.0579
# Time taken for 1 epoch 58.78971195220947 sec
#
# Epoch 22 Batch 0 Loss 0.0208
# Epoch 22 Batch 100 Loss 0.0652
# Epoch 22 Batch 200 Loss 0.0423
# Epoch 22 Batch 300 Loss 0.0482
# Epoch 22 Batch 400 Loss 0.0253
# Epoch 22 Batch 500 Loss 0.0737
# Epoch 22 Batch 600 Loss 0.0488
# Epoch 22 Batch 700 Loss 0.0976
# Epoch 22 Batch 800 Loss 0.0758
# Epoch 22 Batch 900 Loss 0.0843
# Epoch 22 Batch 1000 Loss 0.0441
# Epoch 22 Batch 1100 Loss 0.0889
# Epoch 22 Batch 1200 Loss 0.0721
# Epoch 22 Loss 0.0572
# Time taken for 1 epoch 59.53879451751709 sec
#
# Epoch 23 Batch 0 Loss 0.0173
# Epoch 23 Batch 100 Loss 0.0230
# Epoch 23 Batch 200 Loss 0.0362
# Epoch 23 Batch 300 Loss 0.0437
# Epoch 23 Batch 400 Loss 0.0550
# Epoch 23 Batch 500 Loss 0.0551
# Epoch 23 Batch 600 Loss 0.0847
# Epoch 23 Batch 700 Loss 0.0466
# Epoch 23 Batch 800 Loss 0.0612
# Epoch 23 Batch 900 Loss 0.0700
# Epoch 23 Batch 1000 Loss 0.0835
# Epoch 23 Batch 1100 Loss 0.0558
# Epoch 23 Batch 1200 Loss 0.0779
# Epoch 23 Loss 0.0561
# Time taken for 1 epoch 58.69915699958801 sec
#
# Epoch 24 Batch 0 Loss 0.0394
# Epoch 24 Batch 100 Loss 0.0654
# Epoch 24 Batch 200 Loss 0.0373
# Epoch 24 Batch 300 Loss 0.0394
# Epoch 24 Batch 400 Loss 0.0432
# Epoch 24 Batch 500 Loss 0.0766
# Epoch 24 Batch 600 Loss 0.0395
# Epoch 24 Batch 700 Loss 0.0885
# Epoch 24 Batch 800 Loss 0.0842
# Epoch 24 Batch 900 Loss 0.0599
# Epoch 24 Batch 1000 Loss 0.0176
# Epoch 24 Batch 1100 Loss 0.0436
# Epoch 24 Batch 1200 Loss 0.0433
# Epoch 24 Loss 0.0548
# Time taken for 1 epoch 59.53080081939697 sec
#
# Epoch 25 Batch 0 Loss 0.0518
# Epoch 25 Batch 100 Loss 0.0620
# Epoch 25 Batch 200 Loss 0.0357
# Epoch 25 Batch 300 Loss 0.0491
# Epoch 25 Batch 400 Loss 0.0541
# Epoch 25 Batch 500 Loss 0.0669
# Epoch 25 Batch 600 Loss 0.0575
# Epoch 25 Batch 700 Loss 0.0673
# Epoch 25 Batch 800 Loss 0.0956
# Epoch 25 Batch 900 Loss 0.0582
# Epoch 25 Batch 1000 Loss 0.0589
# Epoch 25 Batch 1100 Loss 0.0846
# Epoch 25 Batch 1200 Loss 0.0548
# Epoch 25 Loss 0.0539
# Time taken for 1 epoch 58.816784381866455 sec
#
# Epoch 26 Batch 0 Loss 0.0313
# Epoch 26 Batch 100 Loss 0.0781
# Epoch 26 Batch 200 Loss 0.0286
# Epoch 26 Batch 300 Loss 0.0556
# Epoch 26 Batch 400 Loss 0.0480
# Epoch 26 Batch 500 Loss 0.0475
# Epoch 26 Batch 600 Loss 0.0460
# Epoch 26 Batch 700 Loss 0.0531
# Epoch 26 Batch 800 Loss 0.0683
# Epoch 26 Batch 900 Loss 0.1225
# Epoch 26 Batch 1000 Loss 0.0500
# Epoch 26 Batch 1100 Loss 0.0807
# Epoch 26 Batch 1200 Loss 0.0543
# Epoch 26 Loss 0.0533
# Time taken for 1 epoch 59.41388154029846 sec
#
# Epoch 27 Batch 0 Loss 0.0431
# Epoch 27 Batch 100 Loss 0.0560
# Epoch 27 Batch 200 Loss 0.0282
# Epoch 27 Batch 300 Loss 0.0852
# Epoch 27 Batch 400 Loss 0.0262
# Epoch 27 Batch 500 Loss 0.0274
# Epoch 27 Batch 600 Loss 0.0543
# Epoch 27 Batch 700 Loss 0.0551
# Epoch 27 Batch 800 Loss 0.0536
# Epoch 27 Batch 900 Loss 0.0797
# Epoch 27 Batch 1000 Loss 0.0602
# Epoch 27 Batch 1100 Loss 0.0757
# Epoch 27 Batch 1200 Loss 0.0386
# Epoch 27 Loss 0.0522
# Time taken for 1 epoch 58.790961503982544 sec
#
# Epoch 28 Batch 0 Loss 0.0505
# Epoch 28 Batch 100 Loss 0.0504
# Epoch 28 Batch 200 Loss 0.0583
# Epoch 28 Batch 300 Loss 0.0223
# Epoch 28 Batch 400 Loss 0.0626
# Epoch 28 Batch 500 Loss 0.0329
# Epoch 28 Batch 600 Loss 0.0662
# Epoch 28 Batch 700 Loss 0.0624
# Epoch 28 Batch 800 Loss 0.0902
# Epoch 28 Batch 900 Loss 0.0212
# Epoch 28 Batch 1000 Loss 0.0545
# Epoch 28 Batch 1100 Loss 0.0800
# Epoch 28 Batch 1200 Loss 0.0389
# Epoch 28 Loss 0.0519
# Time taken for 1 epoch 59.54555320739746 sec
#
# Epoch 29 Batch 0 Loss 0.0393
# Epoch 29 Batch 100 Loss 0.0484
# Epoch 29 Batch 200 Loss 0.0336
# Epoch 29 Batch 300 Loss 0.0324
# Epoch 29 Batch 400 Loss 0.0356
# Epoch 29 Batch 500 Loss 0.0390
# Epoch 29 Batch 600 Loss 0.0341
# Epoch 29 Batch 700 Loss 0.0455
# Epoch 29 Batch 800 Loss 0.0987
# Epoch 29 Batch 900 Loss 0.0395
# Epoch 29 Batch 1000 Loss 0.0997
# Epoch 29 Batch 1100 Loss 0.0557
# Epoch 29 Batch 1200 Loss 0.0725
# Epoch 29 Loss 0.0505
# Time taken for 1 epoch 58.7698655128479 sec
#
# Epoch 30 Batch 0 Loss 0.0199
# Epoch 30 Batch 100 Loss 0.0266
# Epoch 30 Batch 200 Loss 0.0543
# Epoch 30 Batch 300 Loss 0.0594
# Epoch 30 Batch 400 Loss 0.0313
# Epoch 30 Batch 500 Loss 0.0711
# Epoch 30 Batch 600 Loss 0.0313
# Epoch 30 Batch 700 Loss 0.0518
# Epoch 30 Batch 800 Loss 0.0512
# Epoch 30 Batch 900 Loss 0.0677
# Epoch 30 Batch 1000 Loss 0.0909
# Epoch 30 Batch 1100 Loss 0.0584
# Epoch 30 Batch 1200 Loss 0.0724
# Epoch 30 Loss 0.0502
# Time taken for 1 epoch 59.39250469207764 sec
#
# Epoch 31 Batch 0 Loss 0.0252
# Epoch 31 Batch 100 Loss 0.0721
# Epoch 31 Batch 200 Loss 0.0361
# Epoch 31 Batch 300 Loss 0.0483
# Epoch 31 Batch 400 Loss 0.0273
# Epoch 31 Batch 500 Loss 0.0233
# Epoch 31 Batch 600 Loss 0.0466
# Epoch 31 Batch 700 Loss 0.0545
# Epoch 31 Batch 800 Loss 0.0581
# Epoch 31 Batch 900 Loss 0.0678
# Epoch 31 Batch 1000 Loss 0.0270
# Epoch 31 Batch 1100 Loss 0.1037
# Epoch 31 Batch 1200 Loss 0.0603
# Epoch 31 Loss 0.0491
# Time taken for 1 epoch 58.801464319229126 sec
#
# Epoch 32 Batch 0 Loss 0.0234
# Epoch 32 Batch 100 Loss 0.0359
# Epoch 32 Batch 200 Loss 0.0349
# Epoch 32 Batch 300 Loss 0.0367
# Epoch 32 Batch 400 Loss 0.0328
# Epoch 32 Batch 500 Loss 0.0323
# Epoch 32 Batch 600 Loss 0.0591
# Epoch 32 Batch 700 Loss 0.0409
# Epoch 32 Batch 800 Loss 0.0248
# Epoch 32 Batch 900 Loss 0.0278
# Epoch 32 Batch 1000 Loss 0.0688
# Epoch 32 Batch 1100 Loss 0.0461
# Epoch 32 Batch 1200 Loss 0.0409
# Epoch 32 Loss 0.0487
# Time taken for 1 epoch 59.40842294692993 sec
#
# Epoch 33 Batch 0 Loss 0.0435
# Epoch 33 Batch 100 Loss 0.0450
# Epoch 33 Batch 200 Loss 0.0440
# Epoch 33 Batch 300 Loss 0.0413
# Epoch 33 Batch 400 Loss 0.0455
# Epoch 33 Batch 500 Loss 0.0304
# Epoch 33 Batch 600 Loss 0.0563
# Epoch 33 Batch 700 Loss 0.0585
# Epoch 33 Batch 800 Loss 0.0407
# Epoch 33 Batch 900 Loss 0.0839
# Epoch 33 Batch 1000 Loss 0.0477
# Epoch 33 Batch 1100 Loss 0.0459
# Epoch 33 Batch 1200 Loss 0.0750
# Epoch 33 Loss 0.0481
# Time taken for 1 epoch 58.73495173454285 sec
#
# Epoch 34 Batch 0 Loss 0.0319
# Epoch 34 Batch 100 Loss 0.0388
# Epoch 34 Batch 200 Loss 0.0449
# Epoch 34 Batch 300 Loss 0.0371
# Epoch 34 Batch 400 Loss 0.0401
# Epoch 34 Batch 500 Loss 0.0565
# Epoch 34 Batch 600 Loss 0.0487
# Epoch 34 Batch 700 Loss 0.0737
# Epoch 34 Batch 800 Loss 0.0251
# Epoch 34 Batch 900 Loss 0.0413
# Epoch 34 Batch 1000 Loss 0.0800
# Epoch 34 Batch 1100 Loss 0.0529
# Epoch 34 Batch 1200 Loss 0.0410
# Epoch 34 Loss 0.0477
# Time taken for 1 epoch 59.32423806190491 sec
#
# Epoch 35 Batch 0 Loss 0.0671
# Epoch 35 Batch 100 Loss 0.0333
# Epoch 35 Batch 200 Loss 0.0443
# Epoch 35 Batch 300 Loss 0.0346
# Epoch 35 Batch 400 Loss 0.0310
# Epoch 35 Batch 500 Loss 0.0605
# Epoch 35 Batch 600 Loss 0.0641
# Epoch 35 Batch 700 Loss 0.0586
# Epoch 35 Batch 800 Loss 0.0494
# Epoch 35 Batch 900 Loss 0.0900
# Epoch 35 Batch 1000 Loss 0.0619
# Epoch 35 Batch 1100 Loss 0.0460
# Epoch 35 Batch 1200 Loss 0.0431
# Epoch 35 Loss 0.0467
# Time taken for 1 epoch 58.73241448402405 sec
#
# Epoch 36 Batch 0 Loss 0.0384
# Epoch 36 Batch 100 Loss 0.0221
# Epoch 36 Batch 200 Loss 0.0614
# Epoch 36 Batch 300 Loss 0.0511
# Epoch 36 Batch 400 Loss 0.0420
# Epoch 36 Batch 500 Loss 0.0478
# Epoch 36 Batch 600 Loss 0.0439
# Epoch 36 Batch 700 Loss 0.0447
# Epoch 36 Batch 800 Loss 0.0451
# Epoch 36 Batch 900 Loss 0.0431
# Epoch 36 Batch 1000 Loss 0.0427
# Epoch 36 Batch 1100 Loss 0.0641
# Epoch 36 Batch 1200 Loss 0.0462
# Epoch 36 Loss 0.0463
# Time taken for 1 epoch 59.51172637939453 sec
#
# Epoch 37 Batch 0 Loss 0.0120
# Epoch 37 Batch 100 Loss 0.0265
# Epoch 37 Batch 200 Loss 0.0556
# Epoch 37 Batch 300 Loss 0.0303
# Epoch 37 Batch 400 Loss 0.0494
# Epoch 37 Batch 500 Loss 0.0464
# Epoch 37 Batch 600 Loss 0.0309
# Epoch 37 Batch 700 Loss 0.0538
# Epoch 37 Batch 800 Loss 0.0410
# Epoch 37 Batch 900 Loss 0.0431
# Epoch 37 Batch 1000 Loss 0.0806
# Epoch 37 Batch 1100 Loss 0.0396
# Epoch 37 Batch 1200 Loss 0.0813
# Epoch 37 Loss 0.0456
# Time taken for 1 epoch 58.82932949066162 sec
#
# Epoch 38 Batch 0 Loss 0.0303
# Epoch 38 Batch 100 Loss 0.0468
# Epoch 38 Batch 200 Loss 0.0262
# Epoch 38 Batch 300 Loss 0.0277
# Epoch 38 Batch 400 Loss 0.0712
# Epoch 38 Batch 500 Loss 0.0404
# Epoch 38 Batch 600 Loss 0.0360
# Epoch 38 Batch 700 Loss 0.0291
# Epoch 38 Batch 800 Loss 0.0536
# Epoch 38 Batch 900 Loss 0.0252
# Epoch 38 Batch 1000 Loss 0.0529
# Epoch 38 Batch 1100 Loss 0.0425
# Epoch 38 Batch 1200 Loss 0.0742
# Epoch 38 Loss 0.0452
# Time taken for 1 epoch 59.51694631576538 sec
#
# Epoch 39 Batch 0 Loss 0.0262
# Epoch 39 Batch 100 Loss 0.0355
# Epoch 39 Batch 200 Loss 0.0508
# Epoch 39 Batch 300 Loss 0.0303
# Epoch 39 Batch 400 Loss 0.0553
# Epoch 39 Batch 500 Loss 0.0402
# Epoch 39 Batch 600 Loss 0.0457
# Epoch 39 Batch 700 Loss 0.0496
# Epoch 39 Batch 800 Loss 0.0366
# Epoch 39 Batch 900 Loss 0.0286
# Epoch 39 Batch 1000 Loss 0.0497
# Epoch 39 Batch 1100 Loss 0.0558
# Epoch 39 Batch 1200 Loss 0.0490
# Epoch 39 Loss 0.0445
# Time taken for 1 epoch 58.77967691421509 sec
#
# Epoch 40 Batch 0 Loss 0.0374
# Epoch 40 Batch 100 Loss 0.0390
# Epoch 40 Batch 200 Loss 0.0226
# Epoch 40 Batch 300 Loss 0.0461
# Epoch 40 Batch 400 Loss 0.0788
# Epoch 40 Batch 500 Loss 0.0497
# Epoch 40 Batch 600 Loss 0.0259
# Epoch 40 Batch 700 Loss 0.0458
# Epoch 40 Batch 800 Loss 0.0369
# Epoch 40 Batch 900 Loss 0.0592
# Epoch 40 Batch 1000 Loss 0.0417
# Epoch 40 Batch 1100 Loss 0.0304
# Epoch 40 Batch 1200 Loss 0.0584
# Epoch 40 Loss 0.0446
# Time taken for 1 epoch 59.40398573875427 sec
#
# Epoch 41 Batch 0 Loss 0.0101
# Epoch 41 Batch 100 Loss 0.0396
# Epoch 41 Batch 200 Loss 0.0516
# Epoch 41 Batch 300 Loss 0.0405
# Epoch 41 Batch 400 Loss 0.0503
# Epoch 41 Batch 500 Loss 0.0756
# Epoch 41 Batch 600 Loss 0.0405
# Epoch 41 Batch 700 Loss 0.0451
# Epoch 41 Batch 800 Loss 0.0464
# Epoch 41 Batch 900 Loss 0.0529
# Epoch 41 Batch 1000 Loss 0.0525
# Epoch 41 Batch 1100 Loss 0.0568
# Epoch 41 Batch 1200 Loss 0.0721
# Epoch 41 Loss 0.0442
# Time taken for 1 epoch 58.762775182724 sec
#
# Epoch 42 Batch 0 Loss 0.0451
# Epoch 42 Batch 100 Loss 0.0253
# Epoch 42 Batch 200 Loss 0.0216
# Epoch 42 Batch 300 Loss 0.0555
# Epoch 42 Batch 400 Loss 0.0478
# Epoch 42 Batch 500 Loss 0.0518
# Epoch 42 Batch 600 Loss 0.0456
# Epoch 42 Batch 700 Loss 0.0348
# Epoch 42 Batch 800 Loss 0.0515
# Epoch 42 Batch 900 Loss 0.0353
# Epoch 42 Batch 1000 Loss 0.0450
# Epoch 42 Batch 1100 Loss 0.0523
# Epoch 42 Batch 1200 Loss 0.0525
# Epoch 42 Loss 0.0436
# Time taken for 1 epoch 59.333027601242065 sec
#
# Epoch 43 Batch 0 Loss 0.0325
# Epoch 43 Batch 100 Loss 0.0326
# Epoch 43 Batch 200 Loss 0.0453
# Epoch 43 Batch 300 Loss 0.0416
# Epoch 43 Batch 400 Loss 0.0351
# Epoch 43 Batch 500 Loss 0.0476
# Epoch 43 Batch 600 Loss 0.0237
# Epoch 43 Batch 700 Loss 0.0545
# Epoch 43 Batch 800 Loss 0.0477
# Epoch 43 Batch 900 Loss 0.0477
# Epoch 43 Batch 1000 Loss 0.0420
# Epoch 43 Batch 1100 Loss 0.0936
# Epoch 43 Batch 1200 Loss 0.0543
# Epoch 43 Loss 0.0438
# Time taken for 1 epoch 58.79891514778137 sec
#
# Epoch 44 Batch 0 Loss 0.0273
# Epoch 44 Batch 100 Loss 0.0375
# Epoch 44 Batch 200 Loss 0.0466
# Epoch 44 Batch 300 Loss 0.0248
# Epoch 44 Batch 400 Loss 0.0345
# Epoch 44 Batch 500 Loss 0.0475
# Epoch 44 Batch 600 Loss 0.0388
# Epoch 44 Batch 700 Loss 0.0353
# Epoch 44 Batch 800 Loss 0.0378
# Epoch 44 Batch 900 Loss 0.0238
# Epoch 44 Batch 1000 Loss 0.0449
# Epoch 44 Batch 1100 Loss 0.0487
# Epoch 44 Batch 1200 Loss 0.0474
# Epoch 44 Loss 0.0427
# Time taken for 1 epoch 59.444273948669434 sec
#
# Epoch 45 Batch 0 Loss 0.0242
# Epoch 45 Batch 100 Loss 0.0325
# Epoch 45 Batch 200 Loss 0.0445
# Epoch 45 Batch 300 Loss 0.0573
# Epoch 45 Batch 400 Loss 0.0261
# Epoch 45 Batch 500 Loss 0.0377
# Epoch 45 Batch 600 Loss 0.0444
# Epoch 45 Batch 700 Loss 0.0442
# Epoch 45 Batch 800 Loss 0.0572
# Epoch 45 Batch 900 Loss 0.0440
# Epoch 45 Batch 1000 Loss 0.0538
# Epoch 45 Batch 1100 Loss 0.0565
# Epoch 45 Batch 1200 Loss 0.0325
# Epoch 45 Loss 0.0420
# Time taken for 1 epoch 58.754685401916504 sec
#
# Epoch 46 Batch 0 Loss 0.0327
# Epoch 46 Batch 100 Loss 0.0420
# Epoch 46 Batch 200 Loss 0.0303
# Epoch 46 Batch 300 Loss 0.0818
# Epoch 46 Batch 400 Loss 0.0320
# Epoch 46 Batch 500 Loss 0.0378
# Epoch 46 Batch 600 Loss 0.0666
# Epoch 46 Batch 700 Loss 0.0378
# Epoch 46 Batch 800 Loss 0.0556
# Epoch 46 Batch 900 Loss 0.0390
# Epoch 46 Batch 1000 Loss 0.0686
# Epoch 46 Batch 1100 Loss 0.0705
# Epoch 46 Batch 1200 Loss 0.0401
# Epoch 46 Loss 0.0421
# Time taken for 1 epoch 59.547078371047974 sec
#
# Epoch 47 Batch 0 Loss 0.0145
# Epoch 47 Batch 100 Loss 0.0248
# Epoch 47 Batch 200 Loss 0.0515
# Epoch 47 Batch 300 Loss 0.0398
# Epoch 47 Batch 400 Loss 0.0597
# Epoch 47 Batch 500 Loss 0.0356
# Epoch 47 Batch 600 Loss 0.0604
# Epoch 47 Batch 700 Loss 0.0365
# Epoch 47 Batch 800 Loss 0.0559
# Epoch 47 Batch 900 Loss 0.0457
# Epoch 47 Batch 1000 Loss 0.0252
# Epoch 47 Batch 1100 Loss 0.0246
# Epoch 47 Batch 1200 Loss 0.0299
# Epoch 47 Loss 0.0419
# Time taken for 1 epoch 58.8064124584198 sec
#
# Epoch 48 Batch 0 Loss 0.0595
# Epoch 48 Batch 100 Loss 0.0380
# Epoch 48 Batch 200 Loss 0.0330
# Epoch 48 Batch 300 Loss 0.0167
# Epoch 48 Batch 400 Loss 0.0426
# Epoch 48 Batch 500 Loss 0.0517
# Epoch 48 Batch 600 Loss 0.0507
# Epoch 48 Batch 700 Loss 0.0394
# Epoch 48 Batch 800 Loss 0.0473
# Epoch 48 Batch 900 Loss 0.0525
# Epoch 48 Batch 1000 Loss 0.0320
# Epoch 48 Batch 1100 Loss 0.0534
# Epoch 48 Batch 1200 Loss 0.0638
# Epoch 48 Loss 0.0417
# Time taken for 1 epoch 59.35567593574524 sec
#
# Epoch 49 Batch 0 Loss 0.0429
# Epoch 49 Batch 100 Loss 0.0420
# Epoch 49 Batch 200 Loss 0.0363
# Epoch 49 Batch 300 Loss 0.0293
# Epoch 49 Batch 400 Loss 0.0515
# Epoch 49 Batch 500 Loss 0.0284
# Epoch 49 Batch 600 Loss 0.0477
# Epoch 49 Batch 700 Loss 0.0338
# Epoch 49 Batch 800 Loss 0.0533
# Epoch 49 Batch 900 Loss 0.0513
# Epoch 49 Batch 1000 Loss 0.0476
# Epoch 49 Batch 1100 Loss 0.0395
# Epoch 49 Batch 1200 Loss 0.0454
# Epoch 49 Loss 0.0411
# Time taken for 1 epoch 58.806867837905884 sec
#
# Epoch 50 Batch 0 Loss 0.0644
# Epoch 50 Batch 100 Loss 0.0264
# Epoch 50 Batch 200 Loss 0.0495
# Epoch 50 Batch 300 Loss 0.0361
# Epoch 50 Batch 400 Loss 0.0311
# Epoch 50 Batch 500 Loss 0.0158
# Epoch 50 Batch 600 Loss 0.0240
# Epoch 50 Batch 700 Loss 0.0523
# Epoch 50 Batch 800 Loss 0.0319
# Epoch 50 Batch 900 Loss 0.0620
# Epoch 50 Batch 1000 Loss 0.0393
# Epoch 50 Batch 1100 Loss 0.0436
# Epoch 50 Batch 1200 Loss 0.0500
# Epoch 50 Loss 0.0406
# Time taken for 1 epoch 59.43321108818054 sec

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
test_text = ['Не откладывай на завтра то, что можешь сделать сегодня', 'мама мыла окно',  
            'Маленькой ели холодно зимой', 'мы идем гулять по лесу', 'как мне пройти в библиотеку?']

for text in test_text:
    translate(text)
# Out:
# Input: <start> не откладывай на завтра то , что можешь сделать сегодня <end>
# Predicted translation: don't talk about us . <end>
# Input: <start> мама мыла окно <end>
# Predicted translation: is there a good dog ? <end>
# Input: <start> маленькой ели холодно зимой <end>
# Predicted translation: is the water safe ? <end>
# Input: <start> мы идем гулять по лесу <end>
# Predicted translation: we're going in the meal . <end>
# Input: <start> как мне пройти в библиотеку ? <end>
# Predicted translation: how did i get ? <end>

# %% [markdown]
# **Судя по результату, перевод получился слабым. Словарь ограничен и в случае попадания незнакомого слова модель не производит перевод.**

# %% [markdown]
# ## Attention

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 15, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    query_with_time_axis = tf.expand_dims(query, 1)

    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    attention_weights = tf.nn.softmax(score, axis=1)

    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)

attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))

print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 15, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):

    context_vector, attention_weights = self.attention(hidden, enc_output)

    x = self.embedding(x)

    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    output, state = self.gru(x)

    output = tf.reshape(output, (-1, output.shape[2]))

    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 7335)

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
# !rm -rf ./training_attention_checkpoints

checkpoint_dir = './training_attention_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    for t in range(1, targ.shape[1]):

      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))

  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6649
# Epoch 1 Batch 100 Loss 2.1704
# Epoch 1 Batch 200 Loss 1.7775
# Epoch 1 Batch 300 Loss 1.8856
# Epoch 1 Batch 400 Loss 1.6416
# Epoch 1 Batch 500 Loss 1.4289
# Epoch 1 Batch 600 Loss 1.4313
# Epoch 1 Batch 700 Loss 1.2210
# Epoch 1 Batch 800 Loss 1.2377
# Epoch 1 Batch 900 Loss 1.0873
# Epoch 1 Batch 1000 Loss 0.9483
# Epoch 1 Batch 1100 Loss 1.0418
# Epoch 1 Batch 1200 Loss 0.9377
# Epoch 1 Loss 1.4639
# Time taken for 1 epoch 117.3316400051117 sec
#
# Epoch 2 Batch 0 Loss 0.8809
# Epoch 2 Batch 100 Loss 0.6675
# Epoch 2 Batch 200 Loss 0.7546
# Epoch 2 Batch 300 Loss 0.7112
# Epoch 2 Batch 400 Loss 0.7534
# Epoch 2 Batch 500 Loss 0.6461
# Epoch 2 Batch 600 Loss 0.5290
# Epoch 2 Batch 700 Loss 0.5020
# Epoch 2 Batch 800 Loss 0.5704
# Epoch 2 Batch 900 Loss 0.4586
# Epoch 2 Batch 1000 Loss 0.5290
# Epoch 2 Batch 1100 Loss 0.4623
# Epoch 2 Batch 1200 Loss 0.4815
# Epoch 2 Loss 0.6128
# Time taken for 1 epoch 104.35098552703857 sec
#
# Epoch 3 Batch 0 Loss 0.3659
# Epoch 3 Batch 100 Loss 0.3301
# Epoch 3 Batch 200 Loss 0.3687
# Epoch 3 Batch 300 Loss 0.3136
# Epoch 3 Batch 400 Loss 0.3250
# Epoch 3 Batch 500 Loss 0.3067
# Epoch 3 Batch 600 Loss 0.4188
# Epoch 3 Batch 700 Loss 0.2974
# Epoch 3 Batch 800 Loss 0.3693
# Epoch 3 Batch 900 Loss 0.3693
# Epoch 3 Batch 1000 Loss 0.2953
# Epoch 3 Batch 1100 Loss 0.3739
# Epoch 3 Batch 1200 Loss 0.2889
# Epoch 3 Loss 0.3202
# Time taken for 1 epoch 103.53496742248535 sec
#
# Epoch 4 Batch 0 Loss 0.2052
# Epoch 4 Batch 100 Loss 0.2017
# Epoch 4 Batch 200 Loss 0.2313
# Epoch 4 Batch 300 Loss 0.1868
# Epoch 4 Batch 400 Loss 0.2383
# Epoch 4 Batch 500 Loss 0.2608
# Epoch 4 Batch 600 Loss 0.2258
# Epoch 4 Batch 700 Loss 0.2462
# Epoch 4 Batch 800 Loss 0.1902
# Epoch 4 Batch 900 Loss 0.1783
# Epoch 4 Batch 1000 Loss 0.2259
# Epoch 4 Batch 1100 Loss 0.2240
# Epoch 4 Batch 1200 Loss 0.1881
# Epoch 4 Loss 0.1987
# Time taken for 1 epoch 104.45209789276123 sec
#
# Epoch 5 Batch 0 Loss 0.1325
# Epoch 5 Batch 100 Loss 0.1408
# Epoch 5 Batch 200 Loss 0.0754
# Epoch 5 Batch 300 Loss 0.1322
# Epoch 5 Batch 400 Loss 0.0890
# Epoch 5 Batch 500 Loss 0.0858
# Epoch 5 Batch 600 Loss 0.1376
# Epoch 5 Batch 700 Loss 0.1510
# Epoch 5 Batch 800 Loss 0.1592
# Epoch 5 Batch 900 Loss 0.1042
# Epoch 5 Batch 1000 Loss 0.1633
# Epoch 5 Batch 1100 Loss 0.1090
# Epoch 5 Batch 1200 Loss 0.1481
# Epoch 5 Loss 0.1423
# Time taken for 1 epoch 103.38990569114685 sec
#
# Epoch 6 Batch 0 Loss 0.1188
# Epoch 6 Batch 100 Loss 0.0773
# Epoch 6 Batch 200 Loss 0.0749
# Epoch 6 Batch 300 Loss 0.0823
# Epoch 6 Batch 400 Loss 0.0946
# Epoch 6 Batch 500 Loss 0.1170
# Epoch 6 Batch 600 Loss 0.1267
# Epoch 6 Batch 700 Loss 0.1118
# Epoch 6 Batch 800 Loss 0.1063
# Epoch 6 Batch 900 Loss 0.1404
# Epoch 6 Batch 1000 Loss 0.1723
# Epoch 6 Batch 1100 Loss 0.1296
# Epoch 6 Batch 1200 Loss 0.1410
# Epoch 6 Loss 0.1143
# Time taken for 1 epoch 103.90321397781372 sec
#
# Epoch 7 Batch 0 Loss 0.0877
# Epoch 7 Batch 100 Loss 0.0688
# Epoch 7 Batch 200 Loss 0.1282
# Epoch 7 Batch 300 Loss 0.0639
# Epoch 7 Batch 400 Loss 0.0878
# Epoch 7 Batch 500 Loss 0.1032
# Epoch 7 Batch 600 Loss 0.0875
# Epoch 7 Batch 700 Loss 0.0851
# Epoch 7 Batch 800 Loss 0.1127
# Epoch 7 Batch 900 Loss 0.0862
# Epoch 7 Batch 1000 Loss 0.1426
# Epoch 7 Batch 1100 Loss 0.1081
# Epoch 7 Batch 1200 Loss 0.0862
# Epoch 7 Loss 0.0959
# Time taken for 1 epoch 103.37350463867188 sec
#
# Epoch 8 Batch 0 Loss 0.0657
# Epoch 8 Batch 100 Loss 0.0567
# Epoch 8 Batch 200 Loss 0.1128
# Epoch 8 Batch 300 Loss 0.0893
# Epoch 8 Batch 400 Loss 0.0661
# Epoch 8 Batch 500 Loss 0.0940
# Epoch 8 Batch 600 Loss 0.0794
# Epoch 8 Batch 700 Loss 0.0946
# Epoch 8 Batch 800 Loss 0.0866
# Epoch 8 Batch 900 Loss 0.1003
# Epoch 8 Batch 1000 Loss 0.0917
# Epoch 8 Batch 1100 Loss 0.0886
# Epoch 8 Batch 1200 Loss 0.0925
# Epoch 8 Loss 0.0869
# Time taken for 1 epoch 104.25273776054382 sec
#
# Epoch 9 Batch 0 Loss 0.0437
# Epoch 9 Batch 100 Loss 0.0468
# Epoch 9 Batch 200 Loss 0.0693
# Epoch 9 Batch 300 Loss 0.1257
# Epoch 9 Batch 400 Loss 0.0767
# Epoch 9 Batch 500 Loss 0.0753
# Epoch 9 Batch 600 Loss 0.0977
# Epoch 9 Batch 700 Loss 0.0721
# Epoch 9 Batch 800 Loss 0.0612
# Epoch 9 Batch 900 Loss 0.1088
# Epoch 9 Batch 1000 Loss 0.0875
# Epoch 9 Batch 1100 Loss 0.1132
# Epoch 9 Batch 1200 Loss 0.0769
# Epoch 9 Loss 0.0811
# Time taken for 1 epoch 103.1788694858551 sec
#
# Epoch 10 Batch 0 Loss 0.0795
# Epoch 10 Batch 100 Loss 0.0369
# Epoch 10 Batch 200 Loss 0.0592
# Epoch 10 Batch 300 Loss 0.0955
# Epoch 10 Batch 400 Loss 0.0673
# Epoch 10 Batch 500 Loss 0.0427
# Epoch 10 Batch 600 Loss 0.0677
# Epoch 10 Batch 700 Loss 0.0855
# Epoch 10 Batch 800 Loss 0.1317
# Epoch 10 Batch 900 Loss 0.0829
# Epoch 10 Batch 1000 Loss 0.0864
# Epoch 10 Batch 1100 Loss 0.1052
# Epoch 10 Batch 1200 Loss 0.0989
# Epoch 10 Loss 0.0743
# Time taken for 1 epoch 104.48795199394226 sec
#
# Epoch 11 Batch 0 Loss 0.0480
# Epoch 11 Batch 100 Loss 0.0713
# Epoch 11 Batch 200 Loss 0.0546
# Epoch 11 Batch 300 Loss 0.0595
# Epoch 11 Batch 400 Loss 0.0700
# Epoch 11 Batch 500 Loss 0.0589
# Epoch 11 Batch 600 Loss 0.0476
# Epoch 11 Batch 700 Loss 0.0465
# Epoch 11 Batch 800 Loss 0.0973
# Epoch 11 Batch 900 Loss 0.1114
# Epoch 11 Batch 1000 Loss 0.0982
# Epoch 11 Batch 1100 Loss 0.0377
# Epoch 11 Batch 1200 Loss 0.0539
# Epoch 11 Loss 0.0713
# Time taken for 1 epoch 103.39143347740173 sec
#
# Epoch 12 Batch 0 Loss 0.0617
# Epoch 12 Batch 100 Loss 0.0699
# Epoch 12 Batch 200 Loss 0.0634
# Epoch 12 Batch 300 Loss 0.0496
# Epoch 12 Batch 400 Loss 0.0321
# Epoch 12 Batch 500 Loss 0.0555
# Epoch 12 Batch 600 Loss 0.0610
# Epoch 12 Batch 700 Loss 0.0662
# Epoch 12 Batch 800 Loss 0.0736
# Epoch 12 Batch 900 Loss 0.0880
# Epoch 12 Batch 1000 Loss 0.0843
# Epoch 12 Batch 1100 Loss 0.0560
# Epoch 12 Batch 1200 Loss 0.0746
# Epoch 12 Loss 0.0680
# Time taken for 1 epoch 104.44090509414673 sec
#
# Epoch 13 Batch 0 Loss 0.0580
# Epoch 13 Batch 100 Loss 0.0538
# Epoch 13 Batch 200 Loss 0.0422
# Epoch 13 Batch 300 Loss 0.0363
# Epoch 13 Batch 400 Loss 0.0766
# Epoch 13 Batch 500 Loss 0.0455
# Epoch 13 Batch 600 Loss 0.0824
# Epoch 13 Batch 700 Loss 0.0663
# Epoch 13 Batch 800 Loss 0.0668
# Epoch 13 Batch 900 Loss 0.0788
# Epoch 13 Batch 1000 Loss 0.0718
# Epoch 13 Batch 1100 Loss 0.0948
# Epoch 13 Batch 1200 Loss 0.0578
# Epoch 13 Loss 0.0644
# Time taken for 1 epoch 103.19132256507874 sec
#
# Epoch 14 Batch 0 Loss 0.0354
# Epoch 14 Batch 100 Loss 0.0448
# Epoch 14 Batch 200 Loss 0.0421
# Epoch 14 Batch 300 Loss 0.0456
# Epoch 14 Batch 400 Loss 0.0567
# Epoch 14 Batch 500 Loss 0.0599
# Epoch 14 Batch 600 Loss 0.0750
# Epoch 14 Batch 700 Loss 0.0489
# Epoch 14 Batch 800 Loss 0.0949
# Epoch 14 Batch 900 Loss 0.0496
# Epoch 14 Batch 1000 Loss 0.0550
# Epoch 14 Batch 1100 Loss 0.0474
# Epoch 14 Batch 1200 Loss 0.0634
# Epoch 14 Loss 0.0625
# Time taken for 1 epoch 104.30073237419128 sec
#
# Epoch 15 Batch 0 Loss 0.0416
# Epoch 15 Batch 100 Loss 0.0330
# Epoch 15 Batch 200 Loss 0.0907
# Epoch 15 Batch 300 Loss 0.0436
# Epoch 15 Batch 400 Loss 0.0765
# Epoch 15 Batch 500 Loss 0.0940
# Epoch 15 Batch 600 Loss 0.0541
# Epoch 15 Batch 700 Loss 0.0580
# Epoch 15 Batch 800 Loss 0.0563
# Epoch 15 Batch 900 Loss 0.0414
# Epoch 15 Batch 1000 Loss 0.0668
# Epoch 15 Batch 1100 Loss 0.0550
# Epoch 15 Batch 1200 Loss 0.0824
# Epoch 15 Loss 0.0612
# Time taken for 1 epoch 103.35790824890137 sec
#
# Epoch 16 Batch 0 Loss 0.0427
# Epoch 16 Batch 100 Loss 0.0359
# Epoch 16 Batch 200 Loss 0.0602
# Epoch 16 Batch 300 Loss 0.0663
# Epoch 16 Batch 400 Loss 0.0581
# Epoch 16 Batch 500 Loss 0.0348
# Epoch 16 Batch 600 Loss 0.0771
# Epoch 16 Batch 700 Loss 0.0400
# Epoch 16 Batch 800 Loss 0.0742
# Epoch 16 Batch 900 Loss 0.0769
# Epoch 16 Batch 1000 Loss 0.0869
# Epoch 16 Batch 1100 Loss 0.0889
# Epoch 16 Batch 1200 Loss 0.0523
# Epoch 16 Loss 0.0585
# Time taken for 1 epoch 104.19560623168945 sec
#
# Epoch 17 Batch 0 Loss 0.0513
# Epoch 17 Batch 100 Loss 0.0486
# Epoch 17 Batch 200 Loss 0.0451
# Epoch 17 Batch 300 Loss 0.0485
# Epoch 17 Batch 400 Loss 0.0468
# Epoch 17 Batch 500 Loss 0.0479
# Epoch 17 Batch 600 Loss 0.0631
# Epoch 17 Batch 700 Loss 0.0738
# Epoch 17 Batch 800 Loss 0.0611
# Epoch 17 Batch 900 Loss 0.0597
# Epoch 17 Batch 1000 Loss 0.0410
# Epoch 17 Batch 1100 Loss 0.0613
# Epoch 17 Batch 1200 Loss 0.0633
# Epoch 17 Loss 0.0569
# Time taken for 1 epoch 103.08254623413086 sec
#
# Epoch 18 Batch 0 Loss 0.0486
# Epoch 18 Batch 100 Loss 0.0682
# Epoch 18 Batch 200 Loss 0.0826
# Epoch 18 Batch 300 Loss 0.0646
# Epoch 18 Batch 400 Loss 0.0480
# Epoch 18 Batch 500 Loss 0.0610
# Epoch 18 Batch 600 Loss 0.0645
# Epoch 18 Batch 700 Loss 0.0560
# Epoch 18 Batch 800 Loss 0.0576
# Epoch 18 Batch 900 Loss 0.0716
# Epoch 18 Batch 1000 Loss 0.0539
# Epoch 18 Batch 1100 Loss 0.0731
# Epoch 18 Batch 1200 Loss 0.0686
# Epoch 18 Loss 0.0557
# Time taken for 1 epoch 104.22496294975281 sec
#
# Epoch 19 Batch 0 Loss 0.0610
# Epoch 19 Batch 100 Loss 0.0688
# Epoch 19 Batch 200 Loss 0.0519
# Epoch 19 Batch 300 Loss 0.0356
# Epoch 19 Batch 400 Loss 0.0429
# Epoch 19 Batch 500 Loss 0.0389
# Epoch 19 Batch 600 Loss 0.0873
# Epoch 19 Batch 700 Loss 0.0701
# Epoch 19 Batch 800 Loss 0.0357
# Epoch 19 Batch 900 Loss 0.0320
# Epoch 19 Batch 1000 Loss 0.0546
# Epoch 19 Batch 1100 Loss 0.0577
# Epoch 19 Batch 1200 Loss 0.0702
# Epoch 19 Loss 0.0543
# Time taken for 1 epoch 103.31644034385681 sec
#
# Epoch 20 Batch 0 Loss 0.0749
# Epoch 20 Batch 100 Loss 0.0747
# Epoch 20 Batch 200 Loss 0.0675
# Epoch 20 Batch 300 Loss 0.0408
# Epoch 20 Batch 400 Loss 0.0301
# Epoch 20 Batch 500 Loss 0.0833
# Epoch 20 Batch 600 Loss 0.0457
# Epoch 20 Batch 700 Loss 0.0554
# Epoch 20 Batch 800 Loss 0.0577
# Epoch 20 Batch 900 Loss 0.0551
# Epoch 20 Batch 1000 Loss 0.0623
# Epoch 20 Batch 1100 Loss 0.0482
# Epoch 20 Batch 1200 Loss 0.0581
# Epoch 20 Loss 0.0540
# Time taken for 1 epoch 104.15050506591797 sec
#
# Epoch 21 Batch 0 Loss 0.0448
# Epoch 21 Batch 100 Loss 0.0414
# Epoch 21 Batch 200 Loss 0.0382
# Epoch 21 Batch 300 Loss 0.0669
# Epoch 21 Batch 400 Loss 0.0303
# Epoch 21 Batch 500 Loss 0.0404
# Epoch 21 Batch 600 Loss 0.0637
# Epoch 21 Batch 700 Loss 0.0439
# Epoch 21 Batch 800 Loss 0.0512
# Epoch 21 Batch 900 Loss 0.0480
# Epoch 21 Batch 1000 Loss 0.0614
# Epoch 21 Batch 1100 Loss 0.0598
# Epoch 21 Batch 1200 Loss 0.0574
# Epoch 21 Loss 0.0513
# Time taken for 1 epoch 103.26857399940491 sec
#
# Epoch 22 Batch 0 Loss 0.0389
# Epoch 22 Batch 100 Loss 0.0452
# Epoch 22 Batch 200 Loss 0.0446
# Epoch 22 Batch 300 Loss 0.0516
# Epoch 22 Batch 400 Loss 0.0265
# Epoch 22 Batch 500 Loss 0.0340
# Epoch 22 Batch 600 Loss 0.0250
# Epoch 22 Batch 700 Loss 0.0525
# Epoch 22 Batch 800 Loss 0.0378
# Epoch 22 Batch 900 Loss 0.0350
# Epoch 22 Batch 1000 Loss 0.0645
# Epoch 22 Batch 1100 Loss 0.0571
# Epoch 22 Batch 1200 Loss 0.0328
# Epoch 22 Loss 0.0504
# Time taken for 1 epoch 104.40170454978943 sec
#
# Epoch 23 Batch 0 Loss 0.0587
# Epoch 23 Batch 100 Loss 0.0440
# Epoch 23 Batch 200 Loss 0.0361
# Epoch 23 Batch 300 Loss 0.0628
# Epoch 23 Batch 400 Loss 0.0455
# Epoch 23 Batch 500 Loss 0.0688
# Epoch 23 Batch 600 Loss 0.0467
# Epoch 23 Batch 700 Loss 0.0475
# Epoch 23 Batch 800 Loss 0.0548
# Epoch 23 Batch 900 Loss 0.0504
# Epoch 23 Batch 1000 Loss 0.0423
# Epoch 23 Batch 1100 Loss 0.0505
# Epoch 23 Batch 1200 Loss 0.0519
# Epoch 23 Loss 0.0504
# Time taken for 1 epoch 103.14604449272156 sec
#
# Epoch 24 Batch 0 Loss 0.0291
# Epoch 24 Batch 100 Loss 0.0316
# Epoch 24 Batch 200 Loss 0.0388
# Epoch 24 Batch 300 Loss 0.0567
# Epoch 24 Batch 400 Loss 0.0250
# Epoch 24 Batch 500 Loss 0.0362
# Epoch 24 Batch 600 Loss 0.0479
# Epoch 24 Batch 700 Loss 0.0389
# Epoch 24 Batch 800 Loss 0.0866
# Epoch 24 Batch 900 Loss 0.0443
# Epoch 24 Batch 1000 Loss 0.0453
# Epoch 24 Batch 1100 Loss 0.0417
# Epoch 24 Batch 1200 Loss 0.0704
# Epoch 24 Loss 0.0496
# Time taken for 1 epoch 104.26871824264526 sec
#
# Epoch 25 Batch 0 Loss 0.0188
# Epoch 25 Batch 100 Loss 0.0559
# Epoch 25 Batch 200 Loss 0.0395
# Epoch 25 Batch 300 Loss 0.0378
# Epoch 25 Batch 400 Loss 0.0336
# Epoch 25 Batch 500 Loss 0.0372
# Epoch 25 Batch 600 Loss 0.0459
# Epoch 25 Batch 700 Loss 0.0316
# Epoch 25 Batch 800 Loss 0.0452
# Epoch 25 Batch 900 Loss 0.0587
# Epoch 25 Batch 1000 Loss 0.0746
# Epoch 25 Batch 1100 Loss 0.0536
# Epoch 25 Batch 1200 Loss 0.0602
# Epoch 25 Loss 0.0483
# Time taken for 1 epoch 103.19174361228943 sec
#
# Epoch 26 Batch 0 Loss 0.0292
# Epoch 26 Batch 100 Loss 0.0704
# Epoch 26 Batch 200 Loss 0.0244
# Epoch 26 Batch 300 Loss 0.0290
# Epoch 26 Batch 400 Loss 0.0259
# Epoch 26 Batch 500 Loss 0.0679
# Epoch 26 Batch 600 Loss 0.0733
# Epoch 26 Batch 700 Loss 0.0366
# Epoch 26 Batch 800 Loss 0.0625
# Epoch 26 Batch 900 Loss 0.0366
# Epoch 26 Batch 1000 Loss 0.0829
# Epoch 26 Batch 1100 Loss 0.0499
# Epoch 26 Batch 1200 Loss 0.0302
# Epoch 26 Loss 0.0481
# Time taken for 1 epoch 104.07990717887878 sec
#
# Epoch 27 Batch 0 Loss 0.0331
# Epoch 27 Batch 100 Loss 0.0300
# Epoch 27 Batch 200 Loss 0.0236
# Epoch 27 Batch 300 Loss 0.0379
# Epoch 27 Batch 400 Loss 0.0514
# Epoch 27 Batch 500 Loss 0.0387
# Epoch 27 Batch 600 Loss 0.0435
# Epoch 27 Batch 700 Loss 0.0479
# Epoch 27 Batch 800 Loss 0.0392
# Epoch 27 Batch 900 Loss 0.0563
# Epoch 27 Batch 1000 Loss 0.0392
# Epoch 27 Batch 1100 Loss 0.0469
# Epoch 27 Batch 1200 Loss 0.0479
# Epoch 27 Loss 0.0469
# Time taken for 1 epoch 103.34149098396301 sec
#
# Epoch 28 Batch 0 Loss 0.0410
# Epoch 28 Batch 100 Loss 0.0319
# Epoch 28 Batch 200 Loss 0.0310
# Epoch 28 Batch 300 Loss 0.0301
# Epoch 28 Batch 400 Loss 0.0481
# Epoch 28 Batch 500 Loss 0.0330
# Epoch 28 Batch 600 Loss 0.0394
# Epoch 28 Batch 700 Loss 0.0430
# Epoch 28 Batch 800 Loss 0.0377
# Epoch 28 Batch 900 Loss 0.0549
# Epoch 28 Batch 1000 Loss 0.0591
# Epoch 28 Batch 1100 Loss 0.0504
# Epoch 28 Batch 1200 Loss 0.0396
# Epoch 28 Loss 0.0464
# Time taken for 1 epoch 104.03039789199829 sec
#
# Epoch 29 Batch 0 Loss 0.0551
# Epoch 29 Batch 100 Loss 0.0395
# Epoch 29 Batch 200 Loss 0.0428
# Epoch 29 Batch 300 Loss 0.0474
# Epoch 29 Batch 400 Loss 0.0321
# Epoch 29 Batch 500 Loss 0.0444
# Epoch 29 Batch 600 Loss 0.0386
# Epoch 29 Batch 700 Loss 0.0523
# Epoch 29 Batch 800 Loss 0.0591
# Epoch 29 Batch 900 Loss 0.0471
# Epoch 29 Batch 1000 Loss 0.0439
# Epoch 29 Batch 1100 Loss 0.0530
# Epoch 29 Batch 1200 Loss 0.0310
# Epoch 29 Loss 0.0456
# Time taken for 1 epoch 103.15391135215759 sec
#
# Epoch 30 Batch 0 Loss 0.0390
# Epoch 30 Batch 100 Loss 0.0191
# Epoch 30 Batch 200 Loss 0.0325
# Epoch 30 Batch 300 Loss 0.0487
# Epoch 30 Batch 400 Loss 0.0274
# Epoch 30 Batch 500 Loss 0.0750
# Epoch 30 Batch 600 Loss 0.0596
# Epoch 30 Batch 700 Loss 0.0448
# Epoch 30 Batch 800 Loss 0.0239
# Epoch 30 Batch 900 Loss 0.0372
# Epoch 30 Batch 1000 Loss 0.0695
# Epoch 30 Batch 1100 Loss 0.0567
# Epoch 30 Batch 1200 Loss 0.0549
# Epoch 30 Loss 0.0453
# Time taken for 1 epoch 104.17116260528564 sec
#
# Epoch 31 Batch 0 Loss 0.0319
# Epoch 31 Batch 100 Loss 0.0555
# Epoch 31 Batch 200 Loss 0.0477
# Epoch 31 Batch 300 Loss 0.0631
# Epoch 31 Batch 400 Loss 0.0409
# Epoch 31 Batch 500 Loss 0.0269
# Epoch 31 Batch 600 Loss 0.0527
# Epoch 31 Batch 700 Loss 0.0471
# Epoch 31 Batch 800 Loss 0.0241
# Epoch 31 Batch 900 Loss 0.0669
# Epoch 31 Batch 1000 Loss 0.0420
# Epoch 31 Batch 1100 Loss 0.0422
# Epoch 31 Batch 1200 Loss 0.0711
# Epoch 31 Loss 0.0448
# Time taken for 1 epoch 104.00775980949402 sec
#
# Epoch 32 Batch 0 Loss 0.0271
# Epoch 32 Batch 100 Loss 0.0288
# Epoch 32 Batch 200 Loss 0.0338
# Epoch 32 Batch 300 Loss 0.0455
# Epoch 32 Batch 400 Loss 0.0244
# Epoch 32 Batch 500 Loss 0.0253
# Epoch 32 Batch 600 Loss 0.0410
# Epoch 32 Batch 700 Loss 0.0504
# Epoch 32 Batch 800 Loss 0.0500
# Epoch 32 Batch 900 Loss 0.0579
# Epoch 32 Batch 1000 Loss 0.0417
# Epoch 32 Batch 1100 Loss 0.0499
# Epoch 32 Batch 1200 Loss 0.0329
# Epoch 32 Loss 0.0445
# Time taken for 1 epoch 103.85861134529114 sec
#
# Epoch 33 Batch 0 Loss 0.0329
# Epoch 33 Batch 100 Loss 0.0153
# Epoch 33 Batch 200 Loss 0.0339
# Epoch 33 Batch 300 Loss 0.0387
# Epoch 33 Batch 400 Loss 0.0322
# Epoch 33 Batch 500 Loss 0.0549
# Epoch 33 Batch 600 Loss 0.0401
# Epoch 33 Batch 700 Loss 0.0480
# Epoch 33 Batch 800 Loss 0.0423
# Epoch 33 Batch 900 Loss 0.0439
# Epoch 33 Batch 1000 Loss 0.0469
# Epoch 33 Batch 1100 Loss 0.0471
# Epoch 33 Batch 1200 Loss 0.0481
# Epoch 33 Loss 0.0440
# Time taken for 1 epoch 103.16969203948975 sec
#
# Epoch 34 Batch 0 Loss 0.0338
# Epoch 34 Batch 100 Loss 0.0205
# Epoch 34 Batch 200 Loss 0.0165
# Epoch 34 Batch 300 Loss 0.0375
# Epoch 34 Batch 400 Loss 0.0391
# Epoch 34 Batch 500 Loss 0.0485
# Epoch 34 Batch 600 Loss 0.0315
# Epoch 34 Batch 700 Loss 0.0398
# Epoch 34 Batch 800 Loss 0.0563
# Epoch 34 Batch 900 Loss 0.0371
# Epoch 34 Batch 1000 Loss 0.0523
# Epoch 34 Batch 1100 Loss 0.0414
# Epoch 34 Batch 1200 Loss 0.0494
# Epoch 34 Loss 0.0429
# Time taken for 1 epoch 104.29302382469177 sec
#
# Epoch 35 Batch 0 Loss 0.0399
# Epoch 35 Batch 100 Loss 0.0376
# Epoch 35 Batch 200 Loss 0.0495
# Epoch 35 Batch 300 Loss 0.0359
# Epoch 35 Batch 400 Loss 0.0463
# Epoch 35 Batch 500 Loss 0.0369
# Epoch 35 Batch 600 Loss 0.0385
# Epoch 35 Batch 700 Loss 0.0597
# Epoch 35 Batch 800 Loss 0.0524
# Epoch 35 Batch 900 Loss 0.0605
# Epoch 35 Batch 1000 Loss 0.0446
# Epoch 35 Batch 1100 Loss 0.0580
# Epoch 35 Batch 1200 Loss 0.0277
# Epoch 35 Loss 0.0427
# Time taken for 1 epoch 102.9936854839325 sec
#
# Epoch 36 Batch 0 Loss 0.0373
# Epoch 36 Batch 100 Loss 0.0395
# Epoch 36 Batch 200 Loss 0.0300
# Epoch 36 Batch 300 Loss 0.0462
# Epoch 36 Batch 400 Loss 0.0288
# Epoch 36 Batch 500 Loss 0.0346
# Epoch 36 Batch 600 Loss 0.0462
# Epoch 36 Batch 700 Loss 0.0550
# Epoch 36 Batch 800 Loss 0.0684
# Epoch 36 Batch 900 Loss 0.0500
# Epoch 36 Batch 1000 Loss 0.0521
# Epoch 36 Batch 1100 Loss 0.0465
# Epoch 36 Batch 1200 Loss 0.0724
# Epoch 36 Loss 0.0430
# Time taken for 1 epoch 103.9602599143982 sec
#
# Epoch 37 Batch 0 Loss 0.0462
# Epoch 37 Batch 100 Loss 0.0500
# Epoch 37 Batch 200 Loss 0.0207
# Epoch 37 Batch 300 Loss 0.0467
# Epoch 37 Batch 400 Loss 0.0361
# Epoch 37 Batch 500 Loss 0.0341
# Epoch 37 Batch 600 Loss 0.0297
# Epoch 37 Batch 700 Loss 0.0507
# Epoch 37 Batch 800 Loss 0.0327
# Epoch 37 Batch 900 Loss 0.0427
# Epoch 37 Batch 1000 Loss 0.0446
# Epoch 37 Batch 1100 Loss 0.0696
# Epoch 37 Batch 1200 Loss 0.0321
# Epoch 37 Loss 0.0427
# Time taken for 1 epoch 103.01243782043457 sec
#
# Epoch 38 Batch 0 Loss 0.0092
# Epoch 38 Batch 100 Loss 0.0285
# Epoch 38 Batch 200 Loss 0.0430
# Epoch 38 Batch 300 Loss 0.0289
# Epoch 38 Batch 400 Loss 0.0381
# Epoch 38 Batch 500 Loss 0.0414
# Epoch 38 Batch 600 Loss 0.0559
# Epoch 38 Batch 700 Loss 0.0328
# Epoch 38 Batch 800 Loss 0.0407
# Epoch 38 Batch 900 Loss 0.0794
# Epoch 38 Batch 1000 Loss 0.0340
# Epoch 38 Batch 1100 Loss 0.0624
# Epoch 38 Batch 1200 Loss 0.0327
# Epoch 38 Loss 0.0421
# Time taken for 1 epoch 104.33558011054993 sec
#
# Epoch 39 Batch 0 Loss 0.0283
# Epoch 39 Batch 100 Loss 0.0283
# Epoch 39 Batch 200 Loss 0.0224
# Epoch 39 Batch 300 Loss 0.0180
# Epoch 39 Batch 400 Loss 0.0417
# Epoch 39 Batch 500 Loss 0.0469
# Epoch 39 Batch 600 Loss 0.0438
# Epoch 39 Batch 700 Loss 0.0363
# Epoch 39 Batch 800 Loss 0.0495
# Epoch 39 Batch 900 Loss 0.0660
# Epoch 39 Batch 1000 Loss 0.0497
# Epoch 39 Batch 1100 Loss 0.0618
# Epoch 39 Batch 1200 Loss 0.0660
# Epoch 39 Loss 0.0413
# Time taken for 1 epoch 103.20919966697693 sec
#
# Epoch 40 Batch 0 Loss 0.0338
# Epoch 40 Batch 100 Loss 0.0333
# Epoch 40 Batch 200 Loss 0.0410
# Epoch 40 Batch 300 Loss 0.0361
# Epoch 40 Batch 400 Loss 0.0553
# Epoch 40 Batch 500 Loss 0.0267
# Epoch 40 Batch 600 Loss 0.0310
# Epoch 40 Batch 700 Loss 0.0725
# Epoch 40 Batch 800 Loss 0.0358
# Epoch 40 Batch 900 Loss 0.0470
# Epoch 40 Batch 1000 Loss 0.0535
# Epoch 40 Batch 1100 Loss 0.0279
# Epoch 40 Batch 1200 Loss 0.0367
# Epoch 40 Loss 0.0410
# Time taken for 1 epoch 104.17290210723877 sec
#
# Epoch 41 Batch 0 Loss 0.0236
# Epoch 41 Batch 100 Loss 0.0157
# Epoch 41 Batch 200 Loss 0.0343
# Epoch 41 Batch 300 Loss 0.0450
# Epoch 41 Batch 400 Loss 0.0287
# Epoch 41 Batch 500 Loss 0.0384
# Epoch 41 Batch 600 Loss 0.0351
# Epoch 41 Batch 700 Loss 0.0467
# Epoch 41 Batch 800 Loss 0.0286
# Epoch 41 Batch 900 Loss 0.0408
# Epoch 41 Batch 1000 Loss 0.0682
# Epoch 41 Batch 1100 Loss 0.0457
# Epoch 41 Batch 1200 Loss 0.0452
# Epoch 41 Loss 0.0410
# Time taken for 1 epoch 103.11324214935303 sec
#
# Epoch 42 Batch 0 Loss 0.0296
# Epoch 42 Batch 100 Loss 0.0222
# Epoch 42 Batch 200 Loss 0.0497
# Epoch 42 Batch 300 Loss 0.0320
# Epoch 42 Batch 400 Loss 0.0566
# Epoch 42 Batch 500 Loss 0.0449
# Epoch 42 Batch 600 Loss 0.0342
# Epoch 42 Batch 700 Loss 0.0612
# Epoch 42 Batch 800 Loss 0.0423
# Epoch 42 Batch 900 Loss 0.0154
# Epoch 42 Batch 1000 Loss 0.0629
# Epoch 42 Batch 1100 Loss 0.0755
# Epoch 42 Batch 1200 Loss 0.0689
# Epoch 42 Loss 0.0411
# Time taken for 1 epoch 104.14445209503174 sec
#
# Epoch 43 Batch 0 Loss 0.0290
# Epoch 43 Batch 100 Loss 0.0439
# Epoch 43 Batch 200 Loss 0.0445
# Epoch 43 Batch 300 Loss 0.0277
# Epoch 43 Batch 400 Loss 0.0381
# Epoch 43 Batch 500 Loss 0.0566
# Epoch 43 Batch 600 Loss 0.0429
# Epoch 43 Batch 700 Loss 0.0420
# Epoch 43 Batch 800 Loss 0.0326
# Epoch 43 Batch 900 Loss 0.0410
# Epoch 43 Batch 1000 Loss 0.0575
# Epoch 43 Batch 1100 Loss 0.0347
# Epoch 43 Batch 1200 Loss 0.0376
# Epoch 43 Loss 0.0407
# Time taken for 1 epoch 103.17309951782227 sec
#
# Epoch 44 Batch 0 Loss 0.0250
# Epoch 44 Batch 100 Loss 0.0306
# Epoch 44 Batch 200 Loss 0.0356
# Epoch 44 Batch 300 Loss 0.0519
# Epoch 44 Batch 400 Loss 0.0171
# Epoch 44 Batch 500 Loss 0.0335
# Epoch 44 Batch 600 Loss 0.0445
# Epoch 44 Batch 700 Loss 0.0445
# Epoch 44 Batch 800 Loss 0.0333
# Epoch 44 Batch 900 Loss 0.0433
# Epoch 44 Batch 1000 Loss 0.0420
# Epoch 44 Batch 1100 Loss 0.0460
# Epoch 44 Batch 1200 Loss 0.0428
# Epoch 44 Loss 0.0407
# Time taken for 1 epoch 104.08555245399475 sec
#
# Epoch 45 Batch 0 Loss 0.0275
# Epoch 45 Batch 100 Loss 0.0186
# Epoch 45 Batch 200 Loss 0.0315
# Epoch 45 Batch 300 Loss 0.0353
# Epoch 45 Batch 400 Loss 0.0252
# Epoch 45 Batch 500 Loss 0.0478
# Epoch 45 Batch 600 Loss 0.0366
# Epoch 45 Batch 700 Loss 0.0319
# Epoch 45 Batch 800 Loss 0.0350
# Epoch 45 Batch 900 Loss 0.0392
# Epoch 45 Batch 1000 Loss 0.0249
# Epoch 45 Batch 1100 Loss 0.0363
# Epoch 45 Batch 1200 Loss 0.0563
# Epoch 45 Loss 0.0397
# Time taken for 1 epoch 103.26424598693848 sec
#
# Epoch 46 Batch 0 Loss 0.0402
# Epoch 46 Batch 100 Loss 0.0155
# Epoch 46 Batch 200 Loss 0.0348
# Epoch 46 Batch 300 Loss 0.0391
# Epoch 46 Batch 400 Loss 0.0448
# Epoch 46 Batch 500 Loss 0.0370
# Epoch 46 Batch 600 Loss 0.0464
# Epoch 46 Batch 700 Loss 0.0380
# Epoch 46 Batch 800 Loss 0.0182
# Epoch 46 Batch 900 Loss 0.0550
# Epoch 46 Batch 1000 Loss 0.0317
# Epoch 46 Batch 1100 Loss 0.0389
# Epoch 46 Batch 1200 Loss 0.0648
# Epoch 46 Loss 0.0397
# Time taken for 1 epoch 104.04828596115112 sec
#
# Epoch 47 Batch 0 Loss 0.0415
# Epoch 47 Batch 100 Loss 0.0168
# Epoch 47 Batch 200 Loss 0.0193
# Epoch 47 Batch 300 Loss 0.0244
# Epoch 47 Batch 400 Loss 0.0305
# Epoch 47 Batch 500 Loss 0.0218
# Epoch 47 Batch 600 Loss 0.0285
# Epoch 47 Batch 700 Loss 0.0462
# Epoch 47 Batch 800 Loss 0.0426
# Epoch 47 Batch 900 Loss 0.0690
# Epoch 47 Batch 1000 Loss 0.0474
# Epoch 47 Batch 1100 Loss 0.0602
# Epoch 47 Batch 1200 Loss 0.0452
# Epoch 47 Loss 0.0395
# Time taken for 1 epoch 102.94108939170837 sec
#
# Epoch 48 Batch 0 Loss 0.0185
# Epoch 48 Batch 100 Loss 0.0294
# Epoch 48 Batch 200 Loss 0.0177
# Epoch 48 Batch 300 Loss 0.0517
# Epoch 48 Batch 400 Loss 0.0347
# Epoch 48 Batch 500 Loss 0.0391
# Epoch 48 Batch 600 Loss 0.0453
# Epoch 48 Batch 700 Loss 0.0282
# Epoch 48 Batch 800 Loss 0.0411
# Epoch 48 Batch 900 Loss 0.0434
# Epoch 48 Batch 1000 Loss 0.0717
# Epoch 48 Batch 1100 Loss 0.0335
# Epoch 48 Batch 1200 Loss 0.0369
# Epoch 48 Loss 0.0394
# Time taken for 1 epoch 103.97489190101624 sec
#
# Epoch 49 Batch 0 Loss 0.0196
# Epoch 49 Batch 100 Loss 0.0292
# Epoch 49 Batch 200 Loss 0.0571
# Epoch 49 Batch 300 Loss 0.0293
# Epoch 49 Batch 400 Loss 0.0337
# Epoch 49 Batch 500 Loss 0.0395
# Epoch 49 Batch 600 Loss 0.0374
# Epoch 49 Batch 700 Loss 0.0424
# Epoch 49 Batch 800 Loss 0.0444
# Epoch 49 Batch 900 Loss 0.0484
# Epoch 49 Batch 1000 Loss 0.0404
# Epoch 49 Batch 1100 Loss 0.0575
# Epoch 49 Batch 1200 Loss 0.0437
# Epoch 49 Loss 0.0399
# Time taken for 1 epoch 103.14984726905823 sec
#
# Epoch 50 Batch 0 Loss 0.0352
# Epoch 50 Batch 100 Loss 0.0196
# Epoch 50 Batch 200 Loss 0.0230
# Epoch 50 Batch 300 Loss 0.0269
# Epoch 50 Batch 400 Loss 0.0548
# Epoch 50 Batch 500 Loss 0.0484
# Epoch 50 Batch 600 Loss 0.0335
# Epoch 50 Batch 700 Loss 0.0415
# Epoch 50 Batch 800 Loss 0.0523
# Epoch 50 Batch 900 Loss 0.0462
# Epoch 50 Batch 1000 Loss 0.0395
# Epoch 50 Batch 1100 Loss 0.0294
# Epoch 50 Batch 1200 Loss 0.0359
# Epoch 50 Loss 0.0395
# Time taken for 1 epoch 104.20546126365662 sec

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
test_text = ['Не откладывай на завтра то, что можешь сделать сегодня', 'мама мыла окно',  
            'Маленькой ели холодно зимой', 'мы идем гулять по лесу', 'как мне пройти в библиотеку?']

for text in test_text:
    translate(text)
# Out:
# Input: <start> без труда не выловишь и рыбку из пруда <end>
# Predicted translation: no pain , no gain . <end>
# Input: <start> сделал дело гуляй смело <end>
# Predicted translation: so what i had my we'd ? <end>
# Input: <start> не откладывай на завтра то , что можешь сделать сегодня <end>
# Predicted translation: if fun of us tomorrow . <end>
# Input: <start> мама мыла окно <end>
# Predicted translation: the old is not a window is out . <end>
# Input: <start> маленькой ели холодно зимой <end>
# Predicted translation: what was quite new week . <end>
# Input: <start> мы идем гулять по лесу <end>
# Predicted translation: we'll go like the same head out . <end>
# Input: <start> как мне пройти в библиотеку ? <end>
# Predicted translation: how do i get in the way ? <end>

# %% [markdown]
# **Перевод сетью с вниманием получился еще хуже.**
